# %% [markdown]
# <a href="https://colab.research.google.com/github/LarryGamer/ComputerAlg/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import matplotlib.pyplot as plt

class Polynomial:
    coefArray = []

    def __init__(self, *coefficient):
        self.coefArray = coefficient

    def __str__(self):
        outPutString = ""
        for i in range(len(self.coefArray)-1, -1, -1):
          outPutString += str(self.coefArray[i])
          if i>0:
            outPutString += 'x'
          if i>1:
            outPutString += '^' + str(i)
          if i >0:
            outPutString+='+'
        return outPutString

    def __add__(self, polynom):
        tmpArray = []
        for i in range(min(len(self.coefArray)-1, len(polynom.coefArray)-1), -1, -1):
            tmpArray[i] = self.coefArray[i] + polynom.coefArray[i]
        return Polynomial(tmpArray)

    def __sub__(self, polynom):
        tmpArray = []
        for i in range(min(len(self.coefArray)-1, len(polynom.coefArray)-1), -1, -1):
            tmpArray[i] = self.coefArray[i] - polynom.coefArray[i]
        return Polynomial(tmpArray)

    def evalf(self, x):
        result = 0
        for i in range(len(self.coefArray)-1, -1, -1):
            result += self.coefArray[i] * x ** i
        return result

    def toLatex(self):
        return str(self)

    def show(self):
        print(str(self))

    def diff(self):
        tmpArray = []
        for i in range(1, len(self.coefArray)):
            tmpArray[i-1] = self.coefArray[i] * i
        return Polynomial(tmpArray)

    def plot(self, left, right):
        X, Y = [], []
        n=200
        dx = (right - left) / n
        for i in range(n+1):
            x = left + dx*i
            X.append(x)
            #print(x)
            Y.append(self.evalf(x))
            

        fig, ax = plt.subplots(figsize=(12, 9))
        ax.plot(X, Y, color="green", lw=8)
        plt.show()

# %%
a = Polynomial(3,4,16,16,298)
a.show()
a.plot(-40,40)
# Out:
# 298x^4+16x^3+16x^2+4x+3
